# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Michael Fornalski**

# %% [markdown]
# *I am interested in data science because I like finding the secrets of the data and telling stories with my visualizations. The programming aspect of it is also very fun and useful.*

# %% [markdown]
# ### The code in the cell below (cell 5) is a simple addition of two variables (integers).

# %%
One = 1
Two = 2
print(One+Two)
# Out:
# 3

# %% [markdown]
# - A
# - B
# - C
#
#
# ---
#
#
# 1. A
# 2. B
# 3. C
#
#
# ***
#
# | Header | Header | Header |
# | ---- | ---- | ---- |
# | cell | cell | cell |
# | cell | cell | cell |
# ___
#
# <a href = "https://www.coursera.org"> Coursea Link </a>
#
# ---
#
# ~~This should be enough~~
#
# >Hello?
#
# ```javascript
# One = 1
# Two = 2
# print(One+Two)
# ```
